# %% [markdown]
# # SUREcast on Google Colab
# This notebook clones the SUREcast repository, installs dependencies, and runs the entire multi-branch forecasting pipeline.

# %%
# Clone the repository and install requirements
# !git clone https://github.com/pranav18june/surecast.git
# %cd surecast
# !pip install -r requirements.txt

# %%
# Execute the full SUREcast pipeline
# !python run_pipeline.py
